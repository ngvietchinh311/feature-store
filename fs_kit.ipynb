# %% [markdown]
# # 1. Import Library
# ---

# %%
# Load the autoreload extension
# %load_ext autoreload

# Set autoreload to automatically reload modules before executing code
# %autoreload 2

# %%
# CWD PATH: /data/home/chinhnv3

from MHRR.libs_ini import *
from MHRR.mapping import s3_config_list
from MHRR.mapping import S3_SANDBOX_PATH
from pyspark import StorageLevel
import MHRR.mapping as MAPPING

from typing import *

# %% [markdown]
# # 2. Spark Session Ini
# ---

# %%
# Customized Class
class CustomSparkSession(SparkSession.Builder):
    # Private params
    _BASIC_CONF = {
        "spark.master": "yarn",
        "spark.sql.sources.partitionOverwriteMode": "dynamic",
        "spark.decommission.enabled": "true",
        "spark.storage.decommission.shuffleBlocks.enabled": "true",
        "spark.sql.parquet.compression.codec": "zstd",
        "spark.sql.legacy.timeParserPolicy": "LEGACY",
        "spark.sql.parquet.int96RebaseModeInWrite": "CORRECTED",
        "spark.serializer": "org.apache.spark.serializer.KryoSerializer",
        "spark.executor.heartbeatInterval": "10s",
        "spark.network.timeout": "100s",
        "spark.archives": "/data/shared/lib/pyspark_conda_env.tar.gz#environment",
        "spark.pyspark.python": "./environment/bin/python",
    }

    _S3_COMMON_CONF = {
        "spark.hadoop.fs.s3a.path.style.access": "true",
        "spark.hadoop.fs.s3a.impl": "org.apache.hadoop.fs.s3a.S3AFileSystem",
        "spark.hadoop.fs.s3a.aws.credentials.provider": "org.apache.hadoop.fs.s3a.SimpleAWSCredentialsProvider",
    }

    _DYNAMIC_CONF = {
        "spark.dynamicAllocation.testing": "false",
        "spark.dynamicAllocation.shuffleTracking.enabled": "false",
        "spark.dynamicAllocation.maxExecutors": 5,
        "spark.dynamicAllocation.minExecutors": 0,
        "spark.dynamicAllocation.initialExecutors": 5,
        "spark.dynamicAllocation.executorIdleTimeout": "6000s",
        "spark.dynamicAllocation.cachedExecutorIdleTimeout": "9000s",
        "spark.dynamicAllocation.schedulerBacklogTimeout": "10s",
    }

    def _resource_conf(self, x, y, z):
        return {
            "spark.executor.instances": x,
            "spark.executor.cores": y,
            "spark.executor.memory": z,
        }

    # Customized func 1
    def setting_up_conf(
        self,
        job_name="spark_job",
        executor_instance=1,
        executor_cores=2,
        executor_memory="1g",
        s3_keys=[],
        queue="mhrr",
    ) -> "SparkSession.Builder":
        """
        Initiate Spark Session with all needed configurations

        Params
        ------
        job_name: str
            Spark job name (default: `spark_job`)
        executor_cores: int
            Equivalent to the config of `spark.executor.cores`
        executor_memory: int
            Equivalent to the config of `spark.executor.memory`
        s3_key: dict
            Config or key to access S3, items' keys (`bucket`, `access_key`
            , `secret_key`, `endpoint_url`)

        Returns
        -------
        SparkSession
        """
        self._BASIC_CONF["spark.app.name"] = job_name
        self._BASIC_CONF["spark.yarn.queue"] = queue
        RESOURCE_CONF = self._resource_conf(
            executor_instance, executor_cores, executor_memory
        )

        KEY_CONF = {}

        for s3_key in s3_keys:
            KEY_CONF[f"spark.hadoop.fs.s3a.bucket.{s3_key['bucket']}.access.key"] = (
                s3_key["access_key"]
            )
            KEY_CONF[f"spark.hadoop.fs.s3a.bucket.{s3_key['bucket']}.secret.key"] = (
                s3_key["secret_key"]
            )
            KEY_CONF[f"spark.hadoop.fs.s3a.bucket.{s3_key['bucket']}.endpoint"] = (
                s3_key["endpoint_url"]
            )

        ## Define spark config
        spark_configs = {
            **self._BASIC_CONF,
            **self._S3_COMMON_CONF,
            **RESOURCE_CONF,
            **self._DYNAMIC_CONF,
            **KEY_CONF,
        }

        # Combine all configs to SparkConf
        spark_conf = SparkConf().setAll(spark_configs.items())

        return self.config(conf=spark_conf)

# %%
# Change to queue 'mhkd'
spark_config = CustomSparkSession().setting_up_conf(
    job_name="test", s3_keys=s3_config_list, queue="mhrr"
)

spark = spark_config.getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://dev-kdl-mhkd-sandbox-training-011-bank-mb-group.bank.mb.group:50051">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>test</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# # 3. Feature Store Kit
# ---
# **Design**
# ---
#
# **Core Components**
# |Component |Description |
# | ----------- | ----------- |
# |1. Timely() |Timely Object that represents the time windows |
# |2. GroupedAgg() |Object that represents the aggregation functions |
# |3. Entity() |The entity we want to dive in |
# |4. Dim() |A set of characteristics about the entity |
#
#
# 1. *Entity*
# : An identification form of the thing we want to extract the features all about. Example
#
# 2. *Dim*
# : A sort version of term Dimension which represents for the characteristics of the Entity in a particular section
#
# 4. *Metric*
# : The calculation criteria revolve around the **Entity** & **Dim**.
# ---
# - **NOTES:**
# 1. Only work with Spark DataFrame (`pyspark.sql.dataframe.DataFrame`)
# 2. Data source: `Traffic Violation`
# 3. We are assume all these types of features
# - **Time Features**
# : Times of the day; day of the week; specific holidays...
# - **Lag Features**
# : lag1, lag2, lag4, ... for all existing features(DSGD,, SLGD, previous time steps, ...). Especially **Moving average** (lag1 / lag2, ...)
# - **Window Features**
# : Related to **periodic behavior**(*daily*, *weekly*, *monthly*, ...)
# - **Delta Features**
# : (delta feature, or average by divided 2 different features)

# %%
from fs_kit import FSKitSession, Dimension, AggregationUnit

"""
Dimensions Init
"""

dim1 = Dimension(
    dim_name="BIZ_TYPE",
    dim_values=["casa", "td", "loan"],
    dim_description={
        "casa": "tài khoản thanh toán",
        "td": "tài khoản tiết kiệm",
        "loan": "tài khoản nợ",
    },
)

dim2 = Dimension(
    dim_name="WEEKLY_FREQ",
    dim_values=["weekday", "weekend"],
    dim_description={"weekday": "ngày trong tuần", "weekend": "ngày cuối tuần"},
)

"""
AggregationUnits Init
"""
agg1 = AggregationUnit(
    agg_function="sum",
    target_column="vnd_balance_amount",
    alias="amount",
    desc="doanh số giao dịch",
)

agg2 = AggregationUnit(
    agg_function="count_distinct",
    target_column="TIME_SLOT",
    alias="hour",
    desc="số lượng giờ xuất hiện giao dịch",
)

agg3 = AggregationUnit(
    agg_function="count",
    target_column="*",
    alias="transaction",
    desc="số lượng giao dịch",
)

# %%
source_data = spark.read.option("partitionCol", "txn_date").parquet(
    f"s3a://{s3_config_list[1]['bucket']}/working_zone/s3_live/common_fs_project/select_zone/daily/source=mvmt/DEBIT"
)

# Example usage
session = FSKitSession(
    df=source_data,
    source="mvmt",
    target_entity=["customer_code"],
    dims=[dim1, dim2],
    aggs=[agg1, agg2, agg3],
    time_index="txn_date",
)

# %%
# Access and call dynamically created variables
info = session.l1d.get_agg_features(observe_date=date(2024, 8, 13))
info_2 = session.l1m.get_agg_features(observe_date=date(2024, 9, 1))

# %%
for i in info:
    print(
        i.name,
        i.source,
        i.description,
        i.target_entity,
        i.dim_value,
        i.observe_date,
        i.window_agg,
        i.window_slide,
        sep="\n",
    )
    print("--" * 30)
# Out:
# mvmt_casa_weekday_amount_sum_l1d
# mvmt
# tổng doanh số giao dịch tài khoản thanh toán ngày trong tuần trong vòng 1 ngày gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'casa', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekday'}
# 2024-08-13
# AggregationUnit(agg_function='sum', target_column='vnd_balance_amount', alias='amount', desc='doanh số giao dịch')
# l1d
# ------------------------------------------------------------
# mvmt_casa_weekday_hour_countDistinct_l1d
# mvmt
# đếm riêng biệt số lượng giờ xuất hiện giao dịch tài khoản thanh toán ngày trong tuần trong vòng 1 ngày gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'casa', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekday'}
# 2024-08-13
# AggregationUnit(agg_function='count_distinct', target_column='TIME_SLOT', alias='hour', desc='số lượng giờ xuất hiện giao dịch')
# l1d
# ------------------------------------------------------------
# mvmt_casa_weekday_transaction_count_l1d
# mvmt
# đếm số lượng giao dịch tài khoản thanh toán ngày trong tuần trong vòng 1 ngày gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'casa', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekday'}
# 2024-08-13
# AggregationUnit(agg_function='count', target_column='*', alias='transaction', desc='số lượng giao dịch')
# l1d
# ------------------------------------------------------------
# mvmt_casa_weekend_amount_sum_l1d
# mvmt
# tổng doanh số giao dịch tài khoản thanh toán ngày cuối tuần trong vòng 1 ngày gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'casa', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekend'}
# 2024-08-13
# AggregationUnit(agg_function='sum', target_column='vnd_balance_amount', alias='amount', desc='doanh số giao dịch')
# l1d
# ------------------------------------------------------------
# mvmt_casa_weekend_hour_countDistinct_l1d
# mvmt
# đếm riêng biệt số lượng giờ xuất hiện giao dịch tài khoản thanh toán ngày cuối tuần trong vòng 1 ngày gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'casa', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekend'}
# 2024-08-13
# AggregationUnit(agg_function='count_distinct', target_column='TIME_SLOT', alias='hour', desc='số lượng giờ xuất hiện giao dịch')
# l1d
# ------------------------------------------------------------
# mvmt_casa_weekend_transaction_count_l1d
# mvmt
# đếm số lượng giao dịch tài khoản thanh toán ngày cuối tuần trong vòng 1 ngày gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'casa', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekend'}
# 2024-08-13
# AggregationUnit(agg_function='count', target_column='*', alias='transaction', desc='số lượng giao dịch')
# l1d
# ------------------------------------------------------------
# mvmt_td_weekday_amount_sum_l1d
# mvmt
# tổng doanh số giao dịch tài khoản tiết kiệm ngày trong tuần trong vòng 1 ngày gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'td', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekday'}
# 2024-08-13
# AggregationUnit(agg_function='sum', target_column='vnd_balance_amount', alias='amount', desc='doanh số giao dịch')
# l1d
# ------------------------------------------------------------
# mvmt_td_weekday_hour_countDistinct_l1d
# mvmt
# đếm riêng biệt số lượng giờ xuất hiện giao dịch tài khoản tiết kiệm ngày trong tuần trong vòng 1 ngày gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'td', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekday'}
# 2024-08-13
# AggregationUnit(agg_function='count_distinct', target_column='TIME_SLOT', alias='hour', desc='số lượng giờ xuất hiện giao dịch')
# l1d
# ------------------------------------------------------------
# mvmt_td_weekday_transaction_count_l1d
# mvmt
# đếm số lượng giao dịch tài khoản tiết kiệm ngày trong tuần trong vòng 1 ngày gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'td', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekday'}
# 2024-08-13
# AggregationUnit(agg_function='count', target_column='*', alias='transaction', desc='số lượng giao dịch')
# l1d
# ------------------------------------------------------------
# mvmt_td_weekend_amount_sum_l1d
# mvmt
# tổng doanh số giao dịch tài khoản tiết kiệm ngày cuối tuần trong vòng 1 ngày gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'td', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekend'}
# 2024-08-13
# AggregationUnit(agg_function='sum', target_column='vnd_balance_amount', alias='amount', desc='doanh số giao dịch')
# l1d
# ------------------------------------------------------------
# mvmt_td_weekend_hour_countDistinct_l1d
# mvmt
# đếm riêng biệt số lượng giờ xuất hiện giao dịch tài khoản tiết kiệm ngày cuối tuần trong vòng 1 ngày gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'td', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekend'}
# 2024-08-13
# AggregationUnit(agg_function='count_distinct', target_column='TIME_SLOT', alias='hour', desc='số lượng giờ xuất hiện giao dịch')
# l1d
# ------------------------------------------------------------
# mvmt_td_weekend_transaction_count_l1d
# mvmt
# đếm số lượng giao dịch tài khoản tiết kiệm ngày cuối tuần trong vòng 1 ngày gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'td', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekend'}
# 2024-08-13
# AggregationUnit(agg_function='count', target_column='*', alias='transaction', desc='số lượng giao dịch')
# l1d
# ------------------------------------------------------------
# mvmt_loan_weekday_amount_sum_l1d
# mvmt
# tổng doanh số giao dịch tài khoản nợ ngày trong tuần trong vòng 1 ngày gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'loan', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekday'}
# 2024-08-13
# AggregationUnit(agg_function='sum', target_column='vnd_balance_amount', alias='amount', desc='doanh số giao dịch')
# l1d
# ------------------------------------------------------------
# mvmt_loan_weekday_hour_countDistinct_l1d
# mvmt
# đếm riêng biệt số lượng giờ xuất hiện giao dịch tài khoản nợ ngày trong tuần trong vòng 1 ngày gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'loan', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekday'}
# 2024-08-13
# AggregationUnit(agg_function='count_distinct', target_column='TIME_SLOT', alias='hour', desc='số lượng giờ xuất hiện giao dịch')
# l1d
# ------------------------------------------------------------
# mvmt_loan_weekday_transaction_count_l1d
# mvmt
# đếm số lượng giao dịch tài khoản nợ ngày trong tuần trong vòng 1 ngày gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'loan', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekday'}
# 2024-08-13
# AggregationUnit(agg_function='count', target_column='*', alias='transaction', desc='số lượng giao dịch')
# l1d
# ------------------------------------------------------------
# mvmt_loan_weekend_amount_sum_l1d
# mvmt
# tổng doanh số giao dịch tài khoản nợ ngày cuối tuần trong vòng 1 ngày gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'loan', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekend'}
# 2024-08-13
# AggregationUnit(agg_function='sum', target_column='vnd_balance_amount', alias='amount', desc='doanh số giao dịch')
# l1d
# ------------------------------------------------------------
# mvmt_loan_weekend_hour_countDistinct_l1d
# mvmt
# đếm riêng biệt số lượng giờ xuất hiện giao dịch tài khoản nợ ngày cuối tuần trong vòng 1 ngày gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'loan', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekend'}
# 2024-08-13
# AggregationUnit(agg_function='count_distinct', target_column='TIME_SLOT', alias='hour', desc='số lượng giờ xuất hiện giao dịch')
# l1d
# ------------------------------------------------------------
# mvmt_loan_weekend_transaction_count_l1d
# mvmt
# đếm số lượng giao dịch tài khoản nợ ngày cuối tuần trong vòng 1 ngày gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'loan', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekend'}
# 2024-08-13
# AggregationUnit(agg_function='count', target_column='*', alias='transaction', desc='số lượng giao dịch')
# l1d
# ------------------------------------------------------------

# %%
for i in info_2:
    print(
        i.name,
        i.source,
        i.description,
        i.target_entity,
        i.dim_value,
        i.observe_date,
        i.window_agg,
        i.window_slide,
        sep="\n",
    )
    print("--" * 30)
# Out:
# mvmt_casa_weekday_amount_sum_l1m
# mvmt
# tổng doanh số giao dịch tài khoản thanh toán ngày trong tuần trong vòng 1 tháng gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'casa', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekday'}
# 2024-09-01
# AggregationUnit(agg_function='sum', target_column='vnd_balance_amount', alias='amount', desc='doanh số giao dịch')
# l1m
# ------------------------------------------------------------
# mvmt_casa_weekday_hour_countDistinct_l1m
# mvmt
# đếm riêng biệt số lượng giờ xuất hiện giao dịch tài khoản thanh toán ngày trong tuần trong vòng 1 tháng gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'casa', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekday'}
# 2024-09-01
# AggregationUnit(agg_function='count_distinct', target_column='TIME_SLOT', alias='hour', desc='số lượng giờ xuất hiện giao dịch')
# l1m
# ------------------------------------------------------------
# mvmt_casa_weekday_transaction_count_l1m
# mvmt
# đếm số lượng giao dịch tài khoản thanh toán ngày trong tuần trong vòng 1 tháng gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'casa', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekday'}
# 2024-09-01
# AggregationUnit(agg_function='count', target_column='*', alias='transaction', desc='số lượng giao dịch')
# l1m
# ------------------------------------------------------------
# mvmt_casa_weekend_amount_sum_l1m
# mvmt
# tổng doanh số giao dịch tài khoản thanh toán ngày cuối tuần trong vòng 1 tháng gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'casa', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekend'}
# 2024-09-01
# AggregationUnit(agg_function='sum', target_column='vnd_balance_amount', alias='amount', desc='doanh số giao dịch')
# l1m
# ------------------------------------------------------------
# mvmt_casa_weekend_hour_countDistinct_l1m
# mvmt
# đếm riêng biệt số lượng giờ xuất hiện giao dịch tài khoản thanh toán ngày cuối tuần trong vòng 1 tháng gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'casa', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekend'}
# 2024-09-01
# AggregationUnit(agg_function='count_distinct', target_column='TIME_SLOT', alias='hour', desc='số lượng giờ xuất hiện giao dịch')
# l1m
# ------------------------------------------------------------
# mvmt_casa_weekend_transaction_count_l1m
# mvmt
# đếm số lượng giao dịch tài khoản thanh toán ngày cuối tuần trong vòng 1 tháng gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'casa', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekend'}
# 2024-09-01
# AggregationUnit(agg_function='count', target_column='*', alias='transaction', desc='số lượng giao dịch')
# l1m
# ------------------------------------------------------------
# mvmt_td_weekday_amount_sum_l1m
# mvmt
# tổng doanh số giao dịch tài khoản tiết kiệm ngày trong tuần trong vòng 1 tháng gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'td', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekday'}
# 2024-09-01
# AggregationUnit(agg_function='sum', target_column='vnd_balance_amount', alias='amount', desc='doanh số giao dịch')
# l1m
# ------------------------------------------------------------
# mvmt_td_weekday_hour_countDistinct_l1m
# mvmt
# đếm riêng biệt số lượng giờ xuất hiện giao dịch tài khoản tiết kiệm ngày trong tuần trong vòng 1 tháng gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'td', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekday'}
# 2024-09-01
# AggregationUnit(agg_function='count_distinct', target_column='TIME_SLOT', alias='hour', desc='số lượng giờ xuất hiện giao dịch')
# l1m
# ------------------------------------------------------------
# mvmt_td_weekday_transaction_count_l1m
# mvmt
# đếm số lượng giao dịch tài khoản tiết kiệm ngày trong tuần trong vòng 1 tháng gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'td', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekday'}
# 2024-09-01
# AggregationUnit(agg_function='count', target_column='*', alias='transaction', desc='số lượng giao dịch')
# l1m
# ------------------------------------------------------------
# mvmt_td_weekend_amount_sum_l1m
# mvmt
# tổng doanh số giao dịch tài khoản tiết kiệm ngày cuối tuần trong vòng 1 tháng gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'td', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekend'}
# 2024-09-01
# AggregationUnit(agg_function='sum', target_column='vnd_balance_amount', alias='amount', desc='doanh số giao dịch')
# l1m
# ------------------------------------------------------------
# mvmt_td_weekend_hour_countDistinct_l1m
# mvmt
# đếm riêng biệt số lượng giờ xuất hiện giao dịch tài khoản tiết kiệm ngày cuối tuần trong vòng 1 tháng gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'td', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekend'}
# 2024-09-01
# AggregationUnit(agg_function='count_distinct', target_column='TIME_SLOT', alias='hour', desc='số lượng giờ xuất hiện giao dịch')
# l1m
# ------------------------------------------------------------
# mvmt_td_weekend_transaction_count_l1m
# mvmt
# đếm số lượng giao dịch tài khoản tiết kiệm ngày cuối tuần trong vòng 1 tháng gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'td', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekend'}
# 2024-09-01
# AggregationUnit(agg_function='count', target_column='*', alias='transaction', desc='số lượng giao dịch')
# l1m
# ------------------------------------------------------------
# mvmt_loan_weekday_amount_sum_l1m
# mvmt
# tổng doanh số giao dịch tài khoản nợ ngày trong tuần trong vòng 1 tháng gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'loan', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekday'}
# 2024-09-01
# AggregationUnit(agg_function='sum', target_column='vnd_balance_amount', alias='amount', desc='doanh số giao dịch')
# l1m
# ------------------------------------------------------------
# mvmt_loan_weekday_hour_countDistinct_l1m
# mvmt
# đếm riêng biệt số lượng giờ xuất hiện giao dịch tài khoản nợ ngày trong tuần trong vòng 1 tháng gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'loan', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekday'}
# 2024-09-01
# AggregationUnit(agg_function='count_distinct', target_column='TIME_SLOT', alias='hour', desc='số lượng giờ xuất hiện giao dịch')
# l1m
# ------------------------------------------------------------
# mvmt_loan_weekday_transaction_count_l1m
# mvmt
# đếm số lượng giao dịch tài khoản nợ ngày trong tuần trong vòng 1 tháng gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'loan', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekday'}
# 2024-09-01
# AggregationUnit(agg_function='count', target_column='*', alias='transaction', desc='số lượng giao dịch')
# l1m
# ------------------------------------------------------------
# mvmt_loan_weekend_amount_sum_l1m
# mvmt
# tổng doanh số giao dịch tài khoản nợ ngày cuối tuần trong vòng 1 tháng gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'loan', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekend'}
# 2024-09-01
# AggregationUnit(agg_function='sum', target_column='vnd_balance_amount', alias='amount', desc='doanh số giao dịch')
# l1m
# ------------------------------------------------------------
# mvmt_loan_weekend_hour_countDistinct_l1m
# mvmt
# đếm riêng biệt số lượng giờ xuất hiện giao dịch tài khoản nợ ngày cuối tuần trong vòng 1 tháng gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'loan', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekend'}
# 2024-09-01
# AggregationUnit(agg_function='count_distinct', target_column='TIME_SLOT', alias='hour', desc='số lượng giờ xuất hiện giao dịch')
# l1m
# ------------------------------------------------------------
# mvmt_loan_weekend_transaction_count_l1m
# mvmt
# đếm số lượng giao dịch tài khoản nợ ngày cuối tuần trong vòng 1 tháng gần đây
# ['customer_code']
# {Dimension('BIZ_TYPE', ['casa', 'td', 'loan'], {'casa': 'tài khoản thanh toán', 'td': 'tài khoản tiết kiệm', 'loan': 'tài khoản nợ'}): 'loan', Dimension('WEEKLY_FREQ', ['weekday', 'weekend'], {'weekday': 'ngày trong tuần', 'weekend': 'ngày cuối tuần'}): 'weekend'}
# 2024-09-01
# AggregationUnit(agg_function='count', target_column='*', alias='transaction', desc='số lượng giao dịch')
# l1m
# ------------------------------------------------------------

# %%
session.l1d_vs_l1m.extract_feature()

# %%
session.l1d.extract_feature(observe_date=date(2024, 8, 12)).show(
    truncate=False, vertical=True
)
# Out:
# -RECORD 0-----------------------------------------------
#  customer_code                            | 28005
#  mvmt_casa_weekday_amount_sum_l1d         | null
#  mvmt_casa_weekday_hour_countDistinct_l1d | null
#  mvmt_casa_weekday_transaction_count_l1d  | null
#  mvmt_casa_weekend_amount_sum_l1d         | 1680000.00
#  mvmt_casa_weekend_hour_countDistinct_l1d | 2
#  mvmt_casa_weekend_transaction_count_l1d  | 2
#  mvmt_loan_weekday_amount_sum_l1d         | null
#  mvmt_loan_weekday_hour_countDistinct_l1d | null
#  mvmt_loan_weekday_transaction_count_l1d  | null
#  mvmt_loan_weekend_amount_sum_l1d         | null
#  mvmt_loan_weekend_hour_countDistinct_l1d | null
#  mvmt_loan_weekend_transaction_count_l1d  | null
#  mvmt_td_weekday_amount_sum_l1d           | null
#  mvmt_td_weekday_hour_countDistinct_l1d   | null
#  mvmt_td_weekday_transaction_count_l1d    | null
#  mvmt_td_weekend_amount_sum_l1d           | null
#  mvmt_td_weekend_hour_countDistinct_l1d   | null
#  mvmt_td_weekend_transaction_count_l1d    | null
# -RECORD 1-----------------------------------------------
#  customer_code                            | 216006
#  mvmt_casa_weekday_amount_sum_l1d         | null
#  mvmt_casa_weekday_hour_countDistinct_l1d | null
#  mvmt_casa_weekday_transaction_count_l1d  | null
#  mvmt_casa_weekend_amount_sum_l1d         | 700000.00
#  mvmt_casa_weekend_hour_countDistinct_l1d | 1
#  mvmt_casa_weekend_transaction_count_l1d  | 1
#  mvmt_loan_weekday_amount_sum_l1d         | null
#  mvmt_loan_weekday_hour_countDistinct_l1d | null
#  mvmt_loan_weekday_transaction_count_l1d  | null
#  mvmt_loan_weekend_amount_sum_l1d         | null
#  mvmt_loan_weekend_hour_countDistinct_l1d | null
#  mvmt_loan_weekend_transaction_count_l1d  | null
#  mvmt_td_weekday_amount_sum_l1d           | null
#  mvmt_td_weekday_hour_countDistinct_l1d   | null
#  mvmt_td_weekday_transaction_count_l1d    | null
#  mvmt_td_weekend_amount_sum_l1d           | null
#  mvmt_td_weekend_hour_countDistinct_l1d   | null
#  mvmt_td_weekend_transaction_count_l1d    | null
# -RECORD 2-----------------------------------------------
#  customer_code                            | 354281
#  mvmt_casa_weekday_amount_sum_l1d         | null
#  mvmt_casa_weekday_hour_countDistinct_l1d | null
#  mvmt_casa_weekday_transaction_count_l1d  | null
#  mvmt_casa_weekend_amount_sum_l1d         | 1092000.00
#  mvmt_casa_weekend_hour_countDistinct_l1d | 7
#  mvmt_casa_weekend_transaction_count_l1d  | 12
#  mvmt_loan_weekday_amount_sum_l1d         | null
#  mvmt_loan_weekday_hour_countDistinct_l1d | null
#  mvmt_loan_weekday_transaction_count_l1d  | null
#  mvmt_loan_weekend_amount_sum_l1d         | null
#  mvmt_loan_weekend_hour_countDistinct_l1d | null
#  mvmt_loan_weekend_transaction_count_l1d  | null
#  mvmt_td_weekday_amount_sum_l1d           | null
#  mvmt_td_weekday_hour_countDistinct_l1d   | null
#  mvmt_td_weekday_transaction_count_l1d    | null
#  mvmt_td_weekend_amount_sum_l1d           | null
#  mvmt_td_weekend_hour_countDistinct_l1d   | null
#  mvmt_td_weekend_transaction_count_l1d    | null
# -RECORD 3-----------------------------------------------
#  customer_code                            | 432399
#  mvmt_casa_weekday_amount_sum_l1d         | null
#  mvmt_casa_weekday_hour_countDistinct_l1d | null
#  mvmt_casa_weekday_transaction_count_l1d  | null
#  mvmt_casa_weekend_amount_sum_l1d         | 6000000.00
#  mvmt_casa_weekend_hour_countDistinct_l1d | 1
#  mvmt_casa_weekend_transaction_count_l1d  | 1
#  mvmt_loan_weekday_amount_sum_l1d         | null
#  mvmt_loan_weekday_hour_countDistinct_l1d | null
#  mvmt_loan_weekday_transaction_count_l1d  | null
#  mvmt_loan_weekend_amount_sum_l1d         | null
#  mvmt_loan_weekend_hour_countDistinct_l1d | null
#  mvmt_loan_weekend_transaction_count_l1d  | null
#  mvmt_td_weekday_amount_sum_l1d           | null
#  mvmt_td_weekday_hour_countDistinct_l1d   | null
#  mvmt_td_weekday_transaction_count_l1d    | null
#  mvmt_td_weekend_amount_sum_l1d           | null
#  mvmt_td_weekend_hour_countDistinct_l1d   | null
#  mvmt_td_weekend_transaction_count_l1d    | null
# -RECORD 4-----------------------------------------------
#  customer_code                            | 531400
#  mvmt_casa_weekday_amount_sum_l1d         | null
#  mvmt_casa_weekday_hour_countDistinct_l1d | null
#  mvmt_casa_weekday_transaction_count_l1d  | null
#  mvmt_casa_weekend_amount_sum_l1d         | 100000.00
#  mvmt_casa_weekend_hour_countDistinct_l1d | 1
#  mvmt_casa_weekend_transaction_count_l1d  | 1
#  mvmt_loan_weekday_amount_sum_l1d         | null
#  mvmt_loan_weekday_hour_countDistinct_l1d | null
#  mvmt_loan_weekday_transaction_count_l1d  | null
#  mvmt_loan_weekend_amount_sum_l1d         | null
#  mvmt_loan_weekend_hour_countDistinct_l1d | null
#  mvmt_loan_weekend_transaction_count_l1d  | null
#  mvmt_td_weekday_amount_sum_l1d           | null
#  mvmt_td_weekday_hour_countDistinct_l1d   | null
#  mvmt_td_weekday_transaction_count_l1d    | null
#  mvmt_td_weekend_amount_sum_l1d           | null
#  mvmt_td_weekend_hour_countDistinct_l1d   | null
#  mvmt_td_weekend_transaction_count_l1d    | null
# -RECORD 5-----------------------------------------------
#  customer_code                            | 557791
#  mvmt_casa_weekday_amount_sum_l1d         | null
#  mvmt_casa_weekday_hour_countDistinct_l1d | null
#  mvmt_casa_weekday_transaction_count_l1d  | null
#  mvmt_casa_weekend_amount_sum_l1d         | 48900000.00
#  mvmt_casa_weekend_hour_countDistinct_l1d | 4
#  mvmt_casa_weekend_transaction_count_l1d  | 4
#  mvmt_loan_weekday_amount_sum_l1d         | null
#  mvmt_loan_weekday_hour_countDistinct_l1d | null
#  mvmt_loan_weekday_transaction_count_l1d  | null
#  mvmt_loan_weekend_amount_sum_l1d         | null
#  mvmt_loan_weekend_hour_countDistinct_l1d | null
#  mvmt_loan_weekend_transaction_count_l1d  | null
#  mvmt_td_weekday_amount_sum_l1d           | null
#  mvmt_td_weekday_hour_countDistinct_l1d   | null
#  mvmt_td_weekday_transaction_count_l1d    | null
#  mvmt_td_weekend_amount_sum_l1d           | null
#  mvmt_td_weekend_hour_countDistinct_l1d   | null
#  mvmt_td_weekend_transaction_count_l1d    | null
# -RECORD 6-----------------------------------------------
#  customer_code                            | 579502
#  mvmt_casa_weekday_amount_sum_l1d         | null
#  mvmt_casa_weekday_hour_countDistinct_l1d | null
#  mvmt_casa_weekday_transaction_count_l1d  | null
#  mvmt_casa_weekend_amount_sum_l1d         | 1460000.00
#  mvmt_casa_weekend_hour_countDistinct_l1d | 1
#  mvmt_casa_weekend_transaction_count_l1d  | 1
#  mvmt_loan_weekday_amount_sum_l1d         | null
#  mvmt_loan_weekday_hour_countDistinct_l1d | null
#  mvmt_loan_weekday_transaction_count_l1d  | null
#  mvmt_loan_weekend_amount_sum_l1d         | null
#  mvmt_loan_weekend_hour_countDistinct_l1d | null
#  mvmt_loan_weekend_transaction_count_l1d  | null
#  mvmt_td_weekday_amount_sum_l1d           | null
#  mvmt_td_weekday_hour_countDistinct_l1d   | null
#  mvmt_td_weekday_transaction_count_l1d    | null
#  mvmt_td_weekend_amount_sum_l1d           | null
#  mvmt_td_weekend_hour_countDistinct_l1d   | null
#  mvmt_td_weekend_transaction_count_l1d    | null
# -RECORD 7-----------------------------------------------
#  customer_code                            | 667332
#  mvmt_casa_weekday_amount_sum_l1d         | null
#  mvmt_casa_weekday_hour_countDistinct_l1d | null
#  mvmt_casa_weekday_transaction_count_l1d  | null
#  mvmt_casa_weekend_amount_sum_l1d         | 2000000.00
#  mvmt_casa_weekend_hour_countDistinct_l1d | 1
#  mvmt_casa_weekend_transaction_count_l1d  | 1
#  mvmt_loan_weekday_amount_sum_l1d         | null
#  mvmt_loan_weekday_hour_countDistinct_l1d | null
#  mvmt_loan_weekday_transaction_count_l1d  | null
#  mvmt_loan_weekend_amount_sum_l1d         | null
#  mvmt_loan_weekend_hour_countDistinct_l1d | null
#  mvmt_loan_weekend_transaction_count_l1d  | null
#  mvmt_td_weekday_amount_sum_l1d           | null
#  mvmt_td_weekday_hour_countDistinct_l1d   | null
#  mvmt_td_weekday_transaction_count_l1d    | null
#  mvmt_td_weekend_amount_sum_l1d           | null
#  mvmt_td_weekend_hour_countDistinct_l1d   | null
#  mvmt_td_weekend_transaction_count_l1d    | null
# -RECORD 8-----------------------------------------------
#  customer_code                            | 733827
#  mvmt_casa_weekday_amount_sum_l1d         | null
#  mvmt_casa_weekday_hour_countDistinct_l1d | null
#  mvmt_casa_weekday_transaction_count_l1d  | null
#  mvmt_casa_weekend_amount_sum_l1d         | 500000.00
#  mvmt_casa_weekend_hour_countDistinct_l1d | 1
#  mvmt_casa_weekend_transaction_count_l1d  | 1
#  mvmt_loan_weekday_amount_sum_l1d         | null
#  mvmt_loan_weekday_hour_countDistinct_l1d | null
#  mvmt_loan_weekday_transaction_count_l1d  | null
#  mvmt_loan_weekend_amount_sum_l1d         | null
#  mvmt_loan_weekend_hour_countDistinct_l1d | null
#  mvmt_loan_weekend_transaction_count_l1d  | null
#  mvmt_td_weekday_amount_sum_l1d           | null
#  mvmt_td_weekday_hour_countDistinct_l1d   | null
#  mvmt_td_weekday_transaction_count_l1d    | null
#  mvmt_td_weekend_amount_sum_l1d           | null
#  mvmt_td_weekend_hour_countDistinct_l1d   | null
#  mvmt_td_weekend_transaction_count_l1d    | null
# -RECORD 9-----------------------------------------------
#  customer_code                            | 779847
#  mvmt_casa_weekday_amount_sum_l1d         | null
#  mvmt_casa_weekday_hour_countDistinct_l1d | null
#  mvmt_casa_weekday_transaction_count_l1d  | null
#  mvmt_casa_weekend_amount_sum_l1d         | 4000000.00
#  mvmt_casa_weekend_hour_countDistinct_l1d | 1
#  mvmt_casa_weekend_transaction_count_l1d  | 1
#  mvmt_loan_weekday_amount_sum_l1d         | null
#  mvmt_loan_weekday_hour_countDistinct_l1d | null
#  mvmt_loan_weekday_transaction_count_l1d  | null
#  mvmt_loan_weekend_amount_sum_l1d         | null
#  mvmt_loan_weekend_hour_countDistinct_l1d | null
#  mvmt_loan_weekend_transaction_count_l1d  | null
#  mvmt_td_weekday_amount_sum_l1d           | null
#  mvmt_td_weekday_hour_countDistinct_l1d   | null
#  mvmt_td_weekday_transaction_count_l1d    | null
#  mvmt_td_weekend_amount_sum_l1d           | null
#  mvmt_td_weekend_hour_countDistinct_l1d   | null
#  mvmt_td_weekend_transaction_count_l1d    | null
# -RECORD 10----------------------------------------------
#  customer_code                            | 819391
#  mvmt_casa_weekday_amount_sum_l1d         | null
#  mvmt_casa_weekday_hour_countDistinct_l1d | null
#  mvmt_casa_weekday_transaction_count_l1d  | null
#  mvmt_casa_weekend_amount_sum_l1d         | 500000.00
#  mvmt_casa_weekend_hour_countDistinct_l1d | 1
#  mvmt_casa_weekend_transaction_count_l1d  | 1
#  mvmt_loan_weekday_amount_sum_l1d         | null
#  mvmt_loan_weekday_hour_countDistinct_l1d | null
#  mvmt_loan_weekday_transaction_count_l1d  | null
#  mvmt_loan_weekend_amount_sum_l1d         | null
#  mvmt_loan_weekend_hour_countDistinct_l1d | null
#  mvmt_loan_weekend_transaction_count_l1d  | null
#  mvmt_td_weekday_amount_sum_l1d           | null
#  mvmt_td_weekday_hour_countDistinct_l1d   | null
#  mvmt_td_weekday_transaction_count_l1d    | null
#  mvmt_td_weekend_amount_sum_l1d           | null
#  mvmt_td_weekend_hour_countDistinct_l1d   | null
#  mvmt_td_weekend_transaction_count_l1d    | null
# -RECORD 11----------------------------------------------
#  customer_code                            | 921008
#  mvmt_casa_weekday_amount_sum_l1d         | null
#  mvmt_casa_weekday_hour_countDistinct_l1d | null
#  mvmt_casa_weekday_transaction_count_l1d  | null
#  mvmt_casa_weekend_amount_sum_l1d         | 1000000.00
#  mvmt_casa_weekend_hour_countDistinct_l1d | 1
#  mvmt_casa_weekend_transaction_count_l1d  | 1
#  mvmt_loan_weekday_amount_sum_l1d         | null
#  mvmt_loan_weekday_hour_countDistinct_l1d | null
#  mvmt_loan_weekday_transaction_count_l1d  | null
#  mvmt_loan_weekend_amount_sum_l1d         | null
#  mvmt_loan_weekend_hour_countDistinct_l1d | null
#  mvmt_loan_weekend_transaction_count_l1d  | null
#  mvmt_td_weekday_amount_sum_l1d           | null
#  mvmt_td_weekday_hour_countDistinct_l1d   | null
#  mvmt_td_weekday_transaction_count_l1d    | null
#  mvmt_td_weekend_amount_sum_l1d           | null
#  mvmt_td_weekend_hour_countDistinct_l1d   | null
#  mvmt_td_weekend_transaction_count_l1d    | null
# -RECORD 12----------------------------------------------
#  customer_code                            | 939403
#  mvmt_casa_weekday_amount_sum_l1d         | null
#  mvmt_casa_weekday_hour_countDistinct_l1d | null
#  mvmt_casa_weekday_transaction_count_l1d  | null
#  mvmt_casa_weekend_amount_sum_l1d         | 4000000.00
#  mvmt_casa_weekend_hour_countDistinct_l1d | 1
#  mvmt_casa_weekend_transaction_count_l1d  | 1
#  mvmt_loan_weekday_amount_sum_l1d         | null
#  mvmt_loan_weekday_hour_countDistinct_l1d | null
#  mvmt_loan_weekday_transaction_count_l1d  | null
#  mvmt_loan_weekend_amount_sum_l1d         | null
#  mvmt_loan_weekend_hour_countDistinct_l1d | null
#  mvmt_loan_weekend_transaction_count_l1d  | null
#  mvmt_td_weekday_amount_sum_l1d           | null
#  mvmt_td_weekday_hour_countDistinct_l1d   | null
#  mvmt_td_weekday_transaction_count_l1d    | null
#  mvmt_td_weekend_amount_sum_l1d           | null
#  mvmt_td_weekend_hour_countDistinct_l1d   | null
#  mvmt_td_weekend_transaction_count_l1d    | null
# -RECORD 13----------------------------------------------
#  customer_code                            | 969918
#  mvmt_casa_weekday_amount_sum_l1d         | null
#  mvmt_casa_weekday_hour_countDistinct_l1d | null
#  mvmt_casa_weekday_transaction_count_l1d  | null
#  mvmt_casa_weekend_amount_sum_l1d         | 7200000.00
#  mvmt_casa_weekend_hour_countDistinct_l1d | 4
#  mvmt_casa_weekend_transaction_count_l1d  | 4
#  mvmt_loan_weekday_amount_sum_l1d         | null
#  mvmt_loan_weekday_hour_countDistinct_l1d | null
#  mvmt_loan_weekday_transaction_count_l1d  | null
#  mvmt_loan_weekend_amount_sum_l1d         | null
#  mvmt_loan_weekend_hour_countDistinct_l1d | null
#  mvmt_loan_weekend_transaction_count_l1d  | null
#  mvmt_td_weekday_amount_sum_l1d           | null
#  mvmt_td_weekday_hour_countDistinct_l1d   | null
#  mvmt_td_weekday_transaction_count_l1d    | null
#  mvmt_td_weekend_amount_sum_l1d           | null
#  mvmt_td_weekend_hour_countDistinct_l1d   | null
#  mvmt_td_weekend_transaction_count_l1d    | null
# -RECORD 14----------------------------------------------
#  customer_code                            | 971627
#  mvmt_casa_weekday_amount_sum_l1d         | null
#  mvmt_casa_weekday_hour_countDistinct_l1d | null
#  mvmt_casa_weekday_transaction_count_l1d  | null
#  mvmt_casa_weekend_amount_sum_l1d         | 24000000.00
#  mvmt_casa_weekend_hour_countDistinct_l1d | 1
#  mvmt_casa_weekend_transaction_count_l1d  | 1
#  mvmt_loan_weekday_amount_sum_l1d         | null
#  mvmt_loan_weekday_hour_countDistinct_l1d | null
#  mvmt_loan_weekday_transaction_count_l1d  | null
#  mvmt_loan_weekend_amount_sum_l1d         | null
#  mvmt_loan_weekend_hour_countDistinct_l1d | null
#  mvmt_loan_weekend_transaction_count_l1d  | null
#  mvmt_td_weekday_amount_sum_l1d           | null
#  mvmt_td_weekday_hour_countDistinct_l1d   | null
#  mvmt_td_weekday_transaction_count_l1d    | null
#  mvmt_td_weekend_amount_sum_l1d           | null
#  mvmt_td_weekend_hour_countDistinct_l1d   | null
#  mvmt_td_weekend_transaction_count_l1d    | null
# -RECORD 15----------------------------------------------
#  customer_code                            | 1015587
#  mvmt_casa_weekday_amount_sum_l1d         | null
#  mvmt_casa_weekday_hour_countDistinct_l1d | null
#  mvmt_casa_weekday_transaction_count_l1d  | null
#  mvmt_casa_weekend_amount_sum_l1d         | 2155000.00
#  mvmt_casa_weekend_hour_countDistinct_l1d | 3
#  mvmt_casa_weekend_transaction_count_l1d  | 3
#  mvmt_loan_weekday_amount_sum_l1d         | null
#  mvmt_loan_weekday_hour_countDistinct_l1d | null
#  mvmt_loan_weekday_transaction_count_l1d  | null
#  mvmt_loan_weekend_amount_sum_l1d         | null
#  mvmt_loan_weekend_hour_countDistinct_l1d | null
#  mvmt_loan_weekend_transaction_count_l1d  | null
#  mvmt_td_weekday_amount_sum_l1d           | null
#  mvmt_td_weekday_hour_countDistinct_l1d   | null
#  mvmt_td_weekday_transaction_count_l1d    | null
#  mvmt_td_weekend_amount_sum_l1d           | null
#  mvmt_td_weekend_hour_countDistinct_l1d   | null
#  mvmt_td_weekend_transaction_count_l1d    | null
# -RECORD 16----------------------------------------------
#  customer_code                            | 1040814
#  mvmt_casa_weekday_amount_sum_l1d         | null
#  mvmt_casa_weekday_hour_countDistinct_l1d | null
#  mvmt_casa_weekday_transaction_count_l1d  | null
#  mvmt_casa_weekend_amount_sum_l1d         | 835000.00
#  mvmt_casa_weekend_hour_countDistinct_l1d | 4
#  mvmt_casa_weekend_transaction_count_l1d  | 6
#  mvmt_loan_weekday_amount_sum_l1d         | null
#  mvmt_loan_weekday_hour_countDistinct_l1d | null
#  mvmt_loan_weekday_transaction_count_l1d  | null
#  mvmt_loan_weekend_amount_sum_l1d         | null
#  mvmt_loan_weekend_hour_countDistinct_l1d | null
#  mvmt_loan_weekend_transaction_count_l1d  | null
#  mvmt_td_weekday_amount_sum_l1d           | null
#  mvmt_td_weekday_hour_countDistinct_l1d   | null
#  mvmt_td_weekday_transaction_count_l1d    | null
#  mvmt_td_weekend_amount_sum_l1d           | null
#  mvmt_td_weekend_hour_countDistinct_l1d   | null
#  mvmt_td_weekend_transaction_count_l1d    | null
# -RECORD 17----------------------------------------------
#  customer_code                            | 1056198
#  mvmt_casa_weekday_amount_sum_l1d         | null
#  mvmt_casa_weekday_hour_countDistinct_l1d | null
#  mvmt_casa_weekday_transaction_count_l1d  | null
#  mvmt_casa_weekend_amount_sum_l1d         | 58065000.00
#  mvmt_casa_weekend_hour_countDistinct_l1d | 10
#  mvmt_casa_weekend_transaction_count_l1d  | 17
#  mvmt_loan_weekday_amount_sum_l1d         | null
#  mvmt_loan_weekday_hour_countDistinct_l1d | null
#  mvmt_loan_weekday_transaction_count_l1d  | null
#  mvmt_loan_weekend_amount_sum_l1d         | null
#  mvmt_loan_weekend_hour_countDistinct_l1d | null
#  mvmt_loan_weekend_transaction_count_l1d  | null
#  mvmt_td_weekday_amount_sum_l1d           | null
#  mvmt_td_weekday_hour_countDistinct_l1d   | null
#  mvmt_td_weekday_transaction_count_l1d    | null
#  mvmt_td_weekend_amount_sum_l1d           | null
#  mvmt_td_weekend_hour_countDistinct_l1d   | null
#  mvmt_td_weekend_transaction_count_l1d    | null
# -RECORD 18----------------------------------------------
#  customer_code                            | 1122917
#  mvmt_casa_weekday_amount_sum_l1d         | null
#  mvmt_casa_weekday_hour_countDistinct_l1d | null
#  mvmt_casa_weekday_transaction_count_l1d  | null
#  mvmt_casa_weekend_amount_sum_l1d         | 300000.00
#  mvmt_casa_weekend_hour_countDistinct_l1d | 1
#  mvmt_casa_weekend_transaction_count_l1d  | 1
#  mvmt_loan_weekday_amount_sum_l1d         | null
#  mvmt_loan_weekday_hour_countDistinct_l1d | null
#  mvmt_loan_weekday_transaction_count_l1d  | null
#  mvmt_loan_weekend_amount_sum_l1d         | null
#  mvmt_loan_weekend_hour_countDistinct_l1d | null
#  mvmt_loan_weekend_transaction_count_l1d  | null
#  mvmt_td_weekday_amount_sum_l1d           | null
#  mvmt_td_weekday_hour_countDistinct_l1d   | null
#  mvmt_td_weekday_transaction_count_l1d    | null
#  mvmt_td_weekend_amount_sum_l1d           | null
#  mvmt_td_weekend_hour_countDistinct_l1d   | null
#  mvmt_td_weekend_transaction_count_l1d    | null
# -RECORD 19----------------------------------------------
#  customer_code                            | 1231948
#  mvmt_casa_weekday_amount_sum_l1d         | null
#  mvmt_casa_weekday_hour_countDistinct_l1d | null
#  mvmt_casa_weekday_transaction_count_l1d  | null
#  mvmt_casa_weekend_amount_sum_l1d         | 870000.00
#  mvmt_casa_weekend_hour_countDistinct_l1d | 6
#  mvmt_casa_weekend_transaction_count_l1d  | 7
#  mvmt_loan_weekday_amount_sum_l1d         | null
#  mvmt_loan_weekday_hour_countDistinct_l1d | null
#  mvmt_loan_weekday_transaction_count_l1d  | null
#  mvmt_loan_weekend_amount_sum_l1d         | null
#  mvmt_loan_weekend_hour_countDistinct_l1d | null
#  mvmt_loan_weekend_transaction_count_l1d  | null
#  mvmt_td_weekday_amount_sum_l1d           | null
#  mvmt_td_weekday_hour_countDistinct_l1d   | null
#  mvmt_td_weekday_transaction_count_l1d    | null
#  mvmt_td_weekend_amount_sum_l1d           | null
#  mvmt_td_weekend_hour_countDistinct_l1d   | null
#  mvmt_td_weekend_transaction_count_l1d    | null
# only showing top 20 rows

# %%
session.l1m.extract_feature(observe_date=date(2024, 9, 1)).show(
    truncate=False, vertical=True
)
# Out:
# -RECORD 0------------------------------------------------
#  customer_code                            | 8389
#  mvmt_casa_weekday_amount_sum_l1m         | 265969041.00
#  mvmt_casa_weekday_hour_countDistinct_l1m | 18
#  mvmt_casa_weekday_transaction_count_l1m  | 154
#  mvmt_casa_weekend_amount_sum_l1m         | 109659928.00
#  mvmt_casa_weekend_hour_countDistinct_l1m | 16
#  mvmt_casa_weekend_transaction_count_l1m  | 170
#  mvmt_loan_weekday_amount_sum_l1m         | 512711397.00
#  mvmt_loan_weekday_hour_countDistinct_l1m | 10
#  mvmt_loan_weekday_transaction_count_l1m  | 26
#  mvmt_loan_weekend_amount_sum_l1m         | 75955000.00
#  mvmt_loan_weekend_hour_countDistinct_l1m | 7
#  mvmt_loan_weekend_transaction_count_l1m  | 13
#  mvmt_td_weekday_amount_sum_l1m           | 630000000.00
#  mvmt_td_weekday_hour_countDistinct_l1m   | 1
#  mvmt_td_weekday_transaction_count_l1m    | 1
#  mvmt_td_weekend_amount_sum_l1m           | 37571397.00
#  mvmt_td_weekend_hour_countDistinct_l1m   | 1
#  mvmt_td_weekend_transaction_count_l1m    | 1
# -RECORD 1------------------------------------------------
#  customer_code                            | 41324
#  mvmt_casa_weekday_amount_sum_l1m         | 175000000.00
#  mvmt_casa_weekday_hour_countDistinct_l1m | 2
#  mvmt_casa_weekday_transaction_count_l1m  | 4
#  mvmt_casa_weekend_amount_sum_l1m         | 38003785.00
#  mvmt_casa_weekend_hour_countDistinct_l1m | 2
#  mvmt_casa_weekend_transaction_count_l1m  | 2
#  mvmt_loan_weekday_amount_sum_l1m         | null
#  mvmt_loan_weekday_hour_countDistinct_l1m | null
#  mvmt_loan_weekday_transaction_count_l1m  | null
#  mvmt_loan_weekend_amount_sum_l1m         | null
#  mvmt_loan_weekend_hour_countDistinct_l1m | null
#  mvmt_loan_weekend_transaction_count_l1m  | null
#  mvmt_td_weekday_amount_sum_l1m           | null
#  mvmt_td_weekday_hour_countDistinct_l1m   | null
#  mvmt_td_weekday_transaction_count_l1m    | null
#  mvmt_td_weekend_amount_sum_l1m           | null
#  mvmt_td_weekend_hour_countDistinct_l1m   | null
#  mvmt_td_weekend_transaction_count_l1m    | null
# -RECORD 2------------------------------------------------
#  customer_code                            | 45341
#  mvmt_casa_weekday_amount_sum_l1m         | 417372221.00
#  mvmt_casa_weekday_hour_countDistinct_l1m | 15
#  mvmt_casa_weekday_transaction_count_l1m  | 129
#  mvmt_casa_weekend_amount_sum_l1m         | 3489473.00
#  mvmt_casa_weekend_hour_countDistinct_l1m | 14
#  mvmt_casa_weekend_transaction_count_l1m  | 66
#  mvmt_loan_weekday_amount_sum_l1m         | null
#  mvmt_loan_weekday_hour_countDistinct_l1m | null
#  mvmt_loan_weekday_transaction_count_l1m  | null
#  mvmt_loan_weekend_amount_sum_l1m         | null
#  mvmt_loan_weekend_hour_countDistinct_l1m | null
#  mvmt_loan_weekend_transaction_count_l1m  | null
#  mvmt_td_weekday_amount_sum_l1m           | 400002207.00
#  mvmt_td_weekday_hour_countDistinct_l1m   | 1
#  mvmt_td_weekday_transaction_count_l1m    | 2
#  mvmt_td_weekend_amount_sum_l1m           | 2823014.00
#  mvmt_td_weekend_hour_countDistinct_l1m   | 1
#  mvmt_td_weekend_transaction_count_l1m    | 1
# -RECORD 3------------------------------------------------
#  customer_code                            | 105319
#  mvmt_casa_weekday_amount_sum_l1m         | 16850000.00
#  mvmt_casa_weekday_hour_countDistinct_l1m | 8
#  mvmt_casa_weekday_transaction_count_l1m  | 14
#  mvmt_casa_weekend_amount_sum_l1m         | 5800000.00
#  mvmt_casa_weekend_hour_countDistinct_l1m | 4
#  mvmt_casa_weekend_transaction_count_l1m  | 5
#  mvmt_loan_weekday_amount_sum_l1m         | null
#  mvmt_loan_weekday_hour_countDistinct_l1m | null
#  mvmt_loan_weekday_transaction_count_l1m  | null
#  mvmt_loan_weekend_amount_sum_l1m         | null
#  mvmt_loan_weekend_hour_countDistinct_l1m | null
#  mvmt_loan_weekend_transaction_count_l1m  | null
#  mvmt_td_weekday_amount_sum_l1m           | null
#  mvmt_td_weekday_hour_countDistinct_l1m   | null
#  mvmt_td_weekday_transaction_count_l1m    | null
#  mvmt_td_weekend_amount_sum_l1m           | null
#  mvmt_td_weekend_hour_countDistinct_l1m   | null
#  mvmt_td_weekend_transaction_count_l1m    | null
# -RECORD 4------------------------------------------------
#  customer_code                            | 105796
#  mvmt_casa_weekday_amount_sum_l1m         | 569097639.00
#  mvmt_casa_weekday_hour_countDistinct_l1m | 1
#  mvmt_casa_weekday_transaction_count_l1m  | 2
#  mvmt_casa_weekend_amount_sum_l1m         | null
#  mvmt_casa_weekend_hour_countDistinct_l1m | null
#  mvmt_casa_weekend_transaction_count_l1m  | null
#  mvmt_loan_weekday_amount_sum_l1m         | null
#  mvmt_loan_weekday_hour_countDistinct_l1m | null
#  mvmt_loan_weekday_transaction_count_l1m  | null
#  mvmt_loan_weekend_amount_sum_l1m         | null
#  mvmt_loan_weekend_hour_countDistinct_l1m | null
#  mvmt_loan_weekend_transaction_count_l1m  | null
#  mvmt_td_weekday_amount_sum_l1m           | 500003118.00
#  mvmt_td_weekday_hour_countDistinct_l1m   | 1
#  mvmt_td_weekday_transaction_count_l1m    | 2
#  mvmt_td_weekend_amount_sum_l1m           | 69094521.00
#  mvmt_td_weekend_hour_countDistinct_l1m   | 1
#  mvmt_td_weekend_transaction_count_l1m    | 1
# -RECORD 5------------------------------------------------
#  customer_code                            | 113719
#  mvmt_casa_weekday_amount_sum_l1m         | null
#  mvmt_casa_weekday_hour_countDistinct_l1m | null
#  mvmt_casa_weekday_transaction_count_l1m  | null
#  mvmt_casa_weekend_amount_sum_l1m         | 46.00
#  mvmt_casa_weekend_hour_countDistinct_l1m | 1
#  mvmt_casa_weekend_transaction_count_l1m  | 1
#  mvmt_loan_weekday_amount_sum_l1m         | null
#  mvmt_loan_weekday_hour_countDistinct_l1m | null
#  mvmt_loan_weekday_transaction_count_l1m  | null
#  mvmt_loan_weekend_amount_sum_l1m         | null
#  mvmt_loan_weekend_hour_countDistinct_l1m | null
#  mvmt_loan_weekend_transaction_count_l1m  | null
#  mvmt_td_weekday_amount_sum_l1m           | null
#  mvmt_td_weekday_hour_countDistinct_l1m   | null
#  mvmt_td_weekday_transaction_count_l1m    | null
#  mvmt_td_weekend_amount_sum_l1m           | null
#  mvmt_td_weekend_hour_countDistinct_l1m   | null
#  mvmt_td_weekend_transaction_count_l1m    | null
# -RECORD 6------------------------------------------------
#  customer_code                            | 180823
#  mvmt_casa_weekday_amount_sum_l1m         | 1500000.00
#  mvmt_casa_weekday_hour_countDistinct_l1m | 1
#  mvmt_casa_weekday_transaction_count_l1m  | 1
#  mvmt_casa_weekend_amount_sum_l1m         | 5.00
#  mvmt_casa_weekend_hour_countDistinct_l1m | 1
#  mvmt_casa_weekend_transaction_count_l1m  | 1
#  mvmt_loan_weekday_amount_sum_l1m         | null
#  mvmt_loan_weekday_hour_countDistinct_l1m | null
#  mvmt_loan_weekday_transaction_count_l1m  | null
#  mvmt_loan_weekend_amount_sum_l1m         | null
#  mvmt_loan_weekend_hour_countDistinct_l1m | null
#  mvmt_loan_weekend_transaction_count_l1m  | null
#  mvmt_td_weekday_amount_sum_l1m           | null
#  mvmt_td_weekday_hour_countDistinct_l1m   | null
#  mvmt_td_weekday_transaction_count_l1m    | null
#  mvmt_td_weekend_amount_sum_l1m           | null
#  mvmt_td_weekend_hour_countDistinct_l1m   | null
#  mvmt_td_weekend_transaction_count_l1m    | null
# -RECORD 7------------------------------------------------
#  customer_code                            | 180853
#  mvmt_casa_weekday_amount_sum_l1m         | 231811715.00
#  mvmt_casa_weekday_hour_countDistinct_l1m | 8
#  mvmt_casa_weekday_transaction_count_l1m  | 17
#  mvmt_casa_weekend_amount_sum_l1m         | 26251523.00
#  mvmt_casa_weekend_hour_countDistinct_l1m | 5
#  mvmt_casa_weekend_transaction_count_l1m  | 6
#  mvmt_loan_weekday_amount_sum_l1m         | null
#  mvmt_loan_weekday_hour_countDistinct_l1m | null
#  mvmt_loan_weekday_transaction_count_l1m  | null
#  mvmt_loan_weekend_amount_sum_l1m         | null
#  mvmt_loan_weekend_hour_countDistinct_l1m | null
#  mvmt_loan_weekend_transaction_count_l1m  | null
#  mvmt_td_weekday_amount_sum_l1m           | null
#  mvmt_td_weekday_hour_countDistinct_l1m   | null
#  mvmt_td_weekday_transaction_count_l1m    | null
#  mvmt_td_weekend_amount_sum_l1m           | null
#  mvmt_td_weekend_hour_countDistinct_l1m   | null
#  mvmt_td_weekend_transaction_count_l1m    | null
# -RECORD 8------------------------------------------------
#  customer_code                            | 191896
#  mvmt_casa_weekday_amount_sum_l1m         | 148000000.00
#  mvmt_casa_weekday_hour_countDistinct_l1m | 3
#  mvmt_casa_weekday_transaction_count_l1m  | 3
#  mvmt_casa_weekend_amount_sum_l1m         | 15223.00
#  mvmt_casa_weekend_hour_countDistinct_l1m | 2
#  mvmt_casa_weekend_transaction_count_l1m  | 2
#  mvmt_loan_weekday_amount_sum_l1m         | null
#  mvmt_loan_weekday_hour_countDistinct_l1m | null
#  mvmt_loan_weekday_transaction_count_l1m  | null
#  mvmt_loan_weekend_amount_sum_l1m         | null
#  mvmt_loan_weekend_hour_countDistinct_l1m | null
#  mvmt_loan_weekend_transaction_count_l1m  | null
#  mvmt_td_weekday_amount_sum_l1m           | 5994545.00
#  mvmt_td_weekday_hour_countDistinct_l1m   | 2
#  mvmt_td_weekday_transaction_count_l1m    | 3
#  mvmt_td_weekend_amount_sum_l1m           | null
#  mvmt_td_weekend_hour_countDistinct_l1m   | null
#  mvmt_td_weekend_transaction_count_l1m    | null
# -RECORD 9------------------------------------------------
#  customer_code                            | 219609
#  mvmt_casa_weekday_amount_sum_l1m         | null
#  mvmt_casa_weekday_hour_countDistinct_l1m | null
#  mvmt_casa_weekday_transaction_count_l1m  | null
#  mvmt_casa_weekend_amount_sum_l1m         | 400000178.00
#  mvmt_casa_weekend_hour_countDistinct_l1m | 3
#  mvmt_casa_weekend_transaction_count_l1m  | 3
#  mvmt_loan_weekday_amount_sum_l1m         | 62500000.00
#  mvmt_loan_weekday_hour_countDistinct_l1m | 1
#  mvmt_loan_weekday_transaction_count_l1m  | 1
#  mvmt_loan_weekend_amount_sum_l1m         | 53538776.00
#  mvmt_loan_weekend_hour_countDistinct_l1m | 1
#  mvmt_loan_weekend_transaction_count_l1m  | 1
#  mvmt_td_weekday_amount_sum_l1m           | null
#  mvmt_td_weekday_hour_countDistinct_l1m   | null
#  mvmt_td_weekday_transaction_count_l1m    | null
#  mvmt_td_weekend_amount_sum_l1m           | null
#  mvmt_td_weekend_hour_countDistinct_l1m   | null
#  mvmt_td_weekend_transaction_count_l1m    | null
# -RECORD 10-----------------------------------------------
#  customer_code                            | 259610
#  mvmt_casa_weekday_amount_sum_l1m         | 64790367.00
#  mvmt_casa_weekday_hour_countDistinct_l1m | 12
#  mvmt_casa_weekday_transaction_count_l1m  | 29
#  mvmt_casa_weekend_amount_sum_l1m         | 2475225.00
#  mvmt_casa_weekend_hour_countDistinct_l1m | 8
#  mvmt_casa_weekend_transaction_count_l1m  | 9
#  mvmt_loan_weekday_amount_sum_l1m         | null
#  mvmt_loan_weekday_hour_countDistinct_l1m | null
#  mvmt_loan_weekday_transaction_count_l1m  | null
#  mvmt_loan_weekend_amount_sum_l1m         | null
#  mvmt_loan_weekend_hour_countDistinct_l1m | null
#  mvmt_loan_weekend_transaction_count_l1m  | null
#  mvmt_td_weekday_amount_sum_l1m           | 6531988.00
#  mvmt_td_weekday_hour_countDistinct_l1m   | 4
#  mvmt_td_weekday_transaction_count_l1m    | 11
#  mvmt_td_weekend_amount_sum_l1m           | 500000.00
#  mvmt_td_weekend_hour_countDistinct_l1m   | 1
#  mvmt_td_weekend_transaction_count_l1m    | 1
# -RECORD 11-----------------------------------------------
#  customer_code                            | 268819
#  mvmt_casa_weekday_amount_sum_l1m         | null
#  mvmt_casa_weekday_hour_countDistinct_l1m | null
#  mvmt_casa_weekday_transaction_count_l1m  | null
#  mvmt_casa_weekend_amount_sum_l1m         | null
#  mvmt_casa_weekend_hour_countDistinct_l1m | null
#  mvmt_casa_weekend_transaction_count_l1m  | null
#  mvmt_loan_weekday_amount_sum_l1m         | null
#  mvmt_loan_weekday_hour_countDistinct_l1m | null
#  mvmt_loan_weekday_transaction_count_l1m  | null
#  mvmt_loan_weekend_amount_sum_l1m         | null
#  mvmt_loan_weekend_hour_countDistinct_l1m | null
#  mvmt_loan_weekend_transaction_count_l1m  | null
#  mvmt_td_weekday_amount_sum_l1m           | 5833972.00
#  mvmt_td_weekday_hour_countDistinct_l1m   | 2
#  mvmt_td_weekday_transaction_count_l1m    | 2
#  mvmt_td_weekend_amount_sum_l1m           | null
#  mvmt_td_weekend_hour_countDistinct_l1m   | null
#  mvmt_td_weekend_transaction_count_l1m    | null
# -RECORD 12-----------------------------------------------
#  customer_code                            | 283975
#  mvmt_casa_weekday_amount_sum_l1m         | 915960008.00
#  mvmt_casa_weekday_hour_countDistinct_l1m | 13
#  mvmt_casa_weekday_transaction_count_l1m  | 37
#  mvmt_casa_weekend_amount_sum_l1m         | 207011949.00
#  mvmt_casa_weekend_hour_countDistinct_l1m | 6
#  mvmt_casa_weekend_transaction_count_l1m  | 7
#  mvmt_loan_weekday_amount_sum_l1m         | null
#  mvmt_loan_weekday_hour_countDistinct_l1m | null
#  mvmt_loan_weekday_transaction_count_l1m  | null
#  mvmt_loan_weekend_amount_sum_l1m         | null
#  mvmt_loan_weekend_hour_countDistinct_l1m | null
#  mvmt_loan_weekend_transaction_count_l1m  | null
#  mvmt_td_weekday_amount_sum_l1m           | 1902466.00
#  mvmt_td_weekday_hour_countDistinct_l1m   | 1
#  mvmt_td_weekday_transaction_count_l1m    | 1
#  mvmt_td_weekend_amount_sum_l1m           | null
#  mvmt_td_weekend_hour_countDistinct_l1m   | null
#  mvmt_td_weekend_transaction_count_l1m    | null
# -RECORD 13-----------------------------------------------
#  customer_code                            | 285686
#  mvmt_casa_weekday_amount_sum_l1m         | null
#  mvmt_casa_weekday_hour_countDistinct_l1m | null
#  mvmt_casa_weekday_transaction_count_l1m  | null
#  mvmt_casa_weekend_amount_sum_l1m         | 7.00
#  mvmt_casa_weekend_hour_countDistinct_l1m | 1
#  mvmt_casa_weekend_transaction_count_l1m  | 1
#  mvmt_loan_weekday_amount_sum_l1m         | null
#  mvmt_loan_weekday_hour_countDistinct_l1m | null
#  mvmt_loan_weekday_transaction_count_l1m  | null
#  mvmt_loan_weekend_amount_sum_l1m         | null
#  mvmt_loan_weekend_hour_countDistinct_l1m | null
#  mvmt_loan_weekend_transaction_count_l1m  | null
#  mvmt_td_weekday_amount_sum_l1m           | null
#  mvmt_td_weekday_hour_countDistinct_l1m   | null
#  mvmt_td_weekday_transaction_count_l1m    | null
#  mvmt_td_weekend_amount_sum_l1m           | null
#  mvmt_td_weekend_hour_countDistinct_l1m   | null
#  mvmt_td_weekend_transaction_count_l1m    | null
# -RECORD 14-----------------------------------------------
#  customer_code                            | 304276
#  mvmt_casa_weekday_amount_sum_l1m         | 104039300.00
#  mvmt_casa_weekday_hour_countDistinct_l1m | 9
#  mvmt_casa_weekday_transaction_count_l1m  | 12
#  mvmt_casa_weekend_amount_sum_l1m         | 4408176.00
#  mvmt_casa_weekend_hour_countDistinct_l1m | 4
#  mvmt_casa_weekend_transaction_count_l1m  | 4
#  mvmt_loan_weekday_amount_sum_l1m         | null
#  mvmt_loan_weekday_hour_countDistinct_l1m | null
#  mvmt_loan_weekday_transaction_count_l1m  | null
#  mvmt_loan_weekend_amount_sum_l1m         | null
#  mvmt_loan_weekend_hour_countDistinct_l1m | null
#  mvmt_loan_weekend_transaction_count_l1m  | null
#  mvmt_td_weekday_amount_sum_l1m           | null
#  mvmt_td_weekday_hour_countDistinct_l1m   | null
#  mvmt_td_weekday_transaction_count_l1m    | null
#  mvmt_td_weekend_amount_sum_l1m           | null
#  mvmt_td_weekend_hour_countDistinct_l1m   | null
#  mvmt_td_weekend_transaction_count_l1m    | null
# -RECORD 15-----------------------------------------------
#  customer_code                            | 341531
#  mvmt_casa_weekday_amount_sum_l1m         | 100307274.00
#  mvmt_casa_weekday_hour_countDistinct_l1m | 9
#  mvmt_casa_weekday_transaction_count_l1m  | 17
#  mvmt_casa_weekend_amount_sum_l1m         | 885.00
#  mvmt_casa_weekend_hour_countDistinct_l1m | 1
#  mvmt_casa_weekend_transaction_count_l1m  | 1
#  mvmt_loan_weekday_amount_sum_l1m         | null
#  mvmt_loan_weekday_hour_countDistinct_l1m | null
#  mvmt_loan_weekday_transaction_count_l1m  | null
#  mvmt_loan_weekend_amount_sum_l1m         | null
#  mvmt_loan_weekend_hour_countDistinct_l1m | null
#  mvmt_loan_weekend_transaction_count_l1m  | null
#  mvmt_td_weekday_amount_sum_l1m           | null
#  mvmt_td_weekday_hour_countDistinct_l1m   | null
#  mvmt_td_weekday_transaction_count_l1m    | null
#  mvmt_td_weekend_amount_sum_l1m           | null
#  mvmt_td_weekend_hour_countDistinct_l1m   | null
#  mvmt_td_weekend_transaction_count_l1m    | null
# -RECORD 16-----------------------------------------------
#  customer_code                            | 343109
#  mvmt_casa_weekday_amount_sum_l1m         | null
#  mvmt_casa_weekday_hour_countDistinct_l1m | null
#  mvmt_casa_weekday_transaction_count_l1m  | null
#  mvmt_casa_weekend_amount_sum_l1m         | 4.00
#  mvmt_casa_weekend_hour_countDistinct_l1m | 1
#  mvmt_casa_weekend_transaction_count_l1m  | 1
#  mvmt_loan_weekday_amount_sum_l1m         | null
#  mvmt_loan_weekday_hour_countDistinct_l1m | null
#  mvmt_loan_weekday_transaction_count_l1m  | null
#  mvmt_loan_weekend_amount_sum_l1m         | null
#  mvmt_loan_weekend_hour_countDistinct_l1m | null
#  mvmt_loan_weekend_transaction_count_l1m  | null
#  mvmt_td_weekday_amount_sum_l1m           | null
#  mvmt_td_weekday_hour_countDistinct_l1m   | null
#  mvmt_td_weekday_transaction_count_l1m    | null
#  mvmt_td_weekend_amount_sum_l1m           | null
#  mvmt_td_weekend_hour_countDistinct_l1m   | null
#  mvmt_td_weekend_transaction_count_l1m    | null
# -RECORD 17-----------------------------------------------
#  customer_code                            | 357220
#  mvmt_casa_weekday_amount_sum_l1m         | 9706000.00
#  mvmt_casa_weekday_hour_countDistinct_l1m | 2
#  mvmt_casa_weekday_transaction_count_l1m  | 3
#  mvmt_casa_weekend_amount_sum_l1m         | 4004407.00
#  mvmt_casa_weekend_hour_countDistinct_l1m | 3
#  mvmt_casa_weekend_transaction_count_l1m  | 3
#  mvmt_loan_weekday_amount_sum_l1m         | null
#  mvmt_loan_weekday_hour_countDistinct_l1m | null
#  mvmt_loan_weekday_transaction_count_l1m  | null
#  mvmt_loan_weekend_amount_sum_l1m         | null
#  mvmt_loan_weekend_hour_countDistinct_l1m | null
#  mvmt_loan_weekend_transaction_count_l1m  | null
#  mvmt_td_weekday_amount_sum_l1m           | 842871.00
#  mvmt_td_weekday_hour_countDistinct_l1m   | 1
#  mvmt_td_weekday_transaction_count_l1m    | 2
#  mvmt_td_weekend_amount_sum_l1m           | 247343.00
#  mvmt_td_weekend_hour_countDistinct_l1m   | 1
#  mvmt_td_weekend_transaction_count_l1m    | 1
# -RECORD 18-----------------------------------------------
#  customer_code                            | 365010
#  mvmt_casa_weekday_amount_sum_l1m         | 140915000.00
#  mvmt_casa_weekday_hour_countDistinct_l1m | 7
#  mvmt_casa_weekday_transaction_count_l1m  | 9
#  mvmt_casa_weekend_amount_sum_l1m         | 1175903.00
#  mvmt_casa_weekend_hour_countDistinct_l1m | 2
#  mvmt_casa_weekend_transaction_count_l1m  | 2
#  mvmt_loan_weekday_amount_sum_l1m         | null
#  mvmt_loan_weekday_hour_countDistinct_l1m | null
#  mvmt_loan_weekday_transaction_count_l1m  | null
#  mvmt_loan_weekend_amount_sum_l1m         | null
#  mvmt_loan_weekend_hour_countDistinct_l1m | null
#  mvmt_loan_weekend_transaction_count_l1m  | null
#  mvmt_td_weekday_amount_sum_l1m           | 1026849.00
#  mvmt_td_weekday_hour_countDistinct_l1m   | 2
#  mvmt_td_weekday_transaction_count_l1m    | 2
#  mvmt_td_weekend_amount_sum_l1m           | 500000.00
#  mvmt_td_weekend_hour_countDistinct_l1m   | 1
#  mvmt_td_weekend_transaction_count_l1m    | 1
# -RECORD 19-----------------------------------------------
#  customer_code                            | 370089
#  mvmt_casa_weekday_amount_sum_l1m         | 500000.00
#  mvmt_casa_weekday_hour_countDistinct_l1m | 1
#  mvmt_casa_weekday_transaction_count_l1m  | 1
#  mvmt_casa_weekend_amount_sum_l1m         | 341.00
#  mvmt_casa_weekend_hour_countDistinct_l1m | 1
#  mvmt_casa_weekend_transaction_count_l1m  | 1
#  mvmt_loan_weekday_amount_sum_l1m         | null
#  mvmt_loan_weekday_hour_countDistinct_l1m | null
#  mvmt_loan_weekday_transaction_count_l1m  | null
#  mvmt_loan_weekend_amount_sum_l1m         | null
#  mvmt_loan_weekend_hour_countDistinct_l1m | null
#  mvmt_loan_weekend_transaction_count_l1m  | null
#  mvmt_td_weekday_amount_sum_l1m           | null
#  mvmt_td_weekday_hour_countDistinct_l1m   | null
#  mvmt_td_weekday_transaction_count_l1m    | null
#  mvmt_td_weekend_amount_sum_l1m           | null
#  mvmt_td_weekend_hour_countDistinct_l1m   | null
#  mvmt_td_weekend_transaction_count_l1m    | null
# only showing top 20 rows
